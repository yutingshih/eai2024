# %% [markdown]
# # Knowledge Distillation
# - The concept of **knowledge distillation** is to utilize class probabilities of a higher-capacity model (teacher) as soft targets of a smaller model (student)
# - The implement processes can be divided into several stages:
#   1. Finish the `ResNet()` classes
#   2. Train the teacher model (ResNet34) from scratch
#   3. Train the student model (ResNet18) from scratch, i.e. **without KD**
#   4. Define the `Distiller()` class and `loss_re()`, `loss_fe()` functions
#   5. Train the student model **with KD** from the teacher model in two different ways, response-based and feature based distillation
#   6. Comparison of student models w/ & w/o KD
# - Requirements
#   1. Response-based distillation (35%)
#     - accuracy≥0.8 got 30%, the more improvement the higher score compare with student from scratch
#   2. Feature-based distillation (35%)
#     - same as above
#   3. Report (30%)
#     - Comparison of student models w/ & w/o KD
#     - How you choose the **Temperature** and **alpha** in response-based KD
#     - How you extracte features from the choosing intermediate layers
#     - How you design the loss of your response-based and feature-based KD
#     - Any problems you met & how you solved them

# %% [markdown]
# # Setup

# %%
# !pip install torchinfo
import torch
from torch import nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms, models
from torch.utils.data import DataLoader, random_split
from torchinfo import summary
from tqdm import tqdm
import sys
import numpy as np
import math
import matplotlib.pyplot as plt
import os
# Out:
# Requirement already satisfied: torchinfo in /home/master_112/nn6124030/.local/opt/miniconda3/envs/eai/lib/python3.12/site-packages (1.8.0)

# %%
torch.manual_seed(0)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # Download dataset

# %%
validation_split = 0.2
batch_size = 128

# data augmentation and normalization
transform_train = transforms.Compose([
                    transforms.RandomCrop(32, padding=4),
                    transforms.RandomHorizontalFlip(),
                    transforms.ToTensor(),
                    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

transform_test = transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# download dataset
train_and_val_dataset = torchvision.datasets.CIFAR10(
    root='dataset/',
    train=True,
    transform=transform_train,
    download=True
)

test_dataset = torchvision.datasets.CIFAR10(
    root='dataset/',
    train=False,
    transform=transform_test,
    download=True
)

# split train and validation dataset
train_size = int((1 - validation_split) * len(train_and_val_dataset))
val_size = len(train_and_val_dataset) - train_size
train_dataset, val_dataset = random_split(train_and_val_dataset, [train_size, val_size])

# create dataLoader
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

test_num = len(test_dataset)
test_steps = len(test_loader)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Create teacher and student models

# %% [markdown]
# ## Create Resnet structure

# %% [markdown]
# ![Resnet.png](data:image/png;base64,...)

# %% [markdown]
# - Please finish the rest part of ResNet structure

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channel, out_channel, stride=1, downsample=None, **kwargs):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=in_channel, out_channels=out_channel, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.relu = nn.ReLU()
        self.conv2 = nn.Conv2d(in_channels=out_channel, out_channels=out_channel, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.downsample = downsample

    def forward(self, x):
        identity = x
        if self.downsample is not None:
            identity = self.downsample(x)

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        out += identity
        out = self.relu(out)

        return out

# %%
class ResNet(nn.Module):

    def __init__(self, block, blocks_num, num_classes=1000):
        super(ResNet, self).__init__()
        self.in_channel = 64

        self.conv1 = nn.Conv2d(3, self.in_channel, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(self.in_channel)
        self.relu = nn.ReLU(inplace=True)
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        self.layer1 = self._make_layer(block, 64, blocks_num[0])
        self.layer2 = self._make_layer(block, 128, blocks_num[1], stride=2)
        self.layer3 = self._make_layer(block, 256, blocks_num[2], stride=2)
        self.layer4 = self._make_layer(block, 512, blocks_num[3], stride=2)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(512 * block.expansion, num_classes)

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')

    def _make_layer(self, block, channel, block_num, stride=1):
        downsample = None
        if stride != 1 or self.in_channel != channel * block.expansion:
            downsample = nn.Sequential(
                nn.Conv2d(self.in_channel, channel * block.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(channel * block.expansion))

        layers = []
        layers.append(block(self.in_channel, channel, downsample=downsample, stride=stride))
        self.in_channel = channel * block.expansion

        for _ in range(1, block_num):
            layers.append(block(self.in_channel, channel))

        return nn.Sequential(*layers)

    def forward(self, x):
        #######################################################################################
        # 1. Finish the forward pass and return the output layer as well as hidden features.  #
        # 2. The output layer and hidden features will be used later for distilling.          #
        # 3. You can refer to the ResNet structure illustration to finish it.                 #
        #######################################################################################

        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)

        feature1 = self.layer1(x)
        feature2 = self.layer2(feature1)
        feature3 = self.layer3(feature2)
        feature4 = self.layer4(feature3)

        x = self.avgpool(feature4)
        x = self.fc(x.flatten(start_dim=1))

        return x, [feature1, feature2, feature3, feature4]

def resnet18(num_classes=10):
    return ResNet(BasicBlock, [2, 2, 2, 2], num_classes=num_classes)

def resnet34(num_classes=10):
    return ResNet(BasicBlock, [3, 4, 6, 3], num_classes=num_classes)

# %% [markdown]
# ## Teacher model

# %%
Teacher = resnet34(num_classes=10)  # commment out this line if loading trained teacher model
# Teacher = torch.load('Teacher.pt')  # loading trained teacher model
Teacher = Teacher.to(device)

# %%
summary(Teacher)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ResNet                                   --
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─ReLU: 1-3                              --
# ├─MaxPool2d: 1-4                         --
# ├─Sequential: 1-5                        --
# │    └─BasicBlock: 2-1                   --
# │    │    └─Conv2d: 3-1                  36,864
# │    │    └─BatchNorm2d: 3-2             128
# │    │    └─ReLU: 3-3                    --
# │    │    └─Conv2d: 3-4                  36,864
# │    │    └─BatchNorm2d: 3-5             128
# │    └─BasicBlock: 2-2                   --
# │    │    └─Conv2d: 3-6                  36,864
# │    │    └─BatchNorm2d: 3-7             128
# │    │    └─ReLU: 3-8                    --
# │    │    └─Conv2d: 3-9                  36,864
# │    │    └─BatchNorm2d: 3-10            128
# │    └─BasicBlock: 2-3                   --
# │    │    └─Conv2d: 3-11                 36,864
# │    │    └─BatchNorm2d: 3-12            128
# │    │    └─ReLU: 3-13                   --
# │    │    └─Conv2d: 3-14                 36,864
# │    │    └─BatchNorm2d: 3-15            128
# ├─Sequential: 1-6                        --
# │    └─BasicBlock: 2-4                   --
# │    │    └─Conv2d: 3-16                 73,728
# │    │    └─BatchNorm2d: 3-17            256
# │    │    └─ReLU: 3-18                   --
# │    │    └─Conv2d: 3-19                 147,456
# │    │    └─BatchNorm2d: 3-20            256
# │    │    └─Sequential: 3-21             8,448
# │    └─BasicBlock: 2-5                   --
# │    │    └─Conv2d: 3-22                 147,456
# │    │    └─BatchNorm2d: 3-23            256
# │    │    └─ReLU: 3-24                   --
# │    │    └─Conv2d: 3-25                 147,456
# │    │    └─BatchNorm2d: 3-26            256
# │    └─BasicBlock: 2-6                   --
# │    │    └─Conv2d: 3-27                 147,456
# │    │    └─BatchNorm2d: 3-28            256
# │    │    └─ReLU: 3-29                   --
# │    │    └─Conv2d: 3-30                 147,456
# │    │    └─BatchNorm2d: 3-31            256
# │    └─BasicBlock: 2-7                   --
# │    │    └─Conv2d: 3-32                 147,456
# │    │    └─BatchNorm2d: 3-33            256
# │    │    └─ReLU: 3-34                   --
# │    │    └─Conv2d: 3-35                 147,456
# │    │    └─BatchNorm2d: 3-36            256
# ├─Sequential: 1-7                        --
# │    └─BasicBlock: 2-8                   --
# │    │    └─Conv2d: 3-37                 294,912
# │    │    └─BatchNorm2d: 3-38            512
# │    │    └─ReLU: 3-39                   --
# │    │    └─Conv2d: 3-40                 589,824
# │    │    └─BatchNorm2d: 3-41            512
# │    │    └─Sequential: 3-42             33,280
# │    └─BasicBlock: 2-9                   --
# │    │    └─Conv2d: 3-43                 589,824
# │    │    └─BatchNorm2d: 3-44            512
# │    │    └─ReLU: 3-45                   --
# │    │    └─Conv2d: 3-46                 589,824
# │    │    └─BatchNorm2d: 3-47            512
# │    └─BasicBlock: 2-10                  --
# │    │    └─Conv2d: 3-48                 589,824
# │    │    └─BatchNorm2d: 3-49            512
# │    │    └─ReLU: 3-50                   --
# │    │    └─Conv2d: 3-51                 589,824
# │    │    └─BatchNorm2d: 3-52            512
# │    └─BasicBlock: 2-11                  --
# │    │    └─Conv2d: 3-53                 589,824
# │    │    └─BatchNorm2d: 3-54            512
# │    │    └─ReLU: 3-55                   --
# │    │    └─Conv2d: 3-56                 589,824
# │    │    └─BatchNorm2d: 3-57            512
# │    └─BasicBlock: 2-12                  --
# │    │    └─Conv2d: 3-58                 589,824
# │    │    └─BatchNorm2d: 3-59            512
# │    │    └─ReLU: 3-60                   --
# │    │    └─Conv2d: 3-61                 589,824
# │    │    └─BatchNorm2d: 3-62            512
# │    └─BasicBlock: 2-13                  --
# │    │    └─Conv2d: 3-63                 589,824
# │    │    └─BatchNorm2d: 3-64            512
# │    │    └─ReLU: 3-65                   --
# │    │    └─Conv2d: 3-66                 589,824
# │    │    └─BatchNorm2d: 3-67            512
# ├─Sequential: 1-8                        --
# │    └─BasicBlock: 2-14                  --
# │    │    └─Conv2d: 3-68                 1,179,648
# │    │    └─BatchNorm2d: 3-69            1,024
# │    │    └─ReLU: 3-70                   --
# │    │    └─Conv2d: 3-71                 2,359,296
# │    │    └─BatchNorm2d: 3-72            1,024
# │    │    └─Sequential: 3-73             132,096
# │    └─BasicBlock: 2-15                  --
# │    │    └─Conv2d: 3-74                 2,359,296
# │    │    └─BatchNorm2d: 3-75            1,024
# │    │    └─ReLU: 3-76                   --
# │    │    └─Conv2d: 3-77                 2,359,296
# │    │    └─BatchNorm2d: 3-78            1,024
# │    └─BasicBlock: 2-16                  --
# │    │    └─Conv2d: 3-79                 2,359,296
# │    │    └─BatchNorm2d: 3-80            1,024
# │    │    └─ReLU: 3-81                   --
# │    │    └─Conv2d: 3-82                 2,359,296
# │    │    └─BatchNorm2d: 3-83            1,024
# ├─AdaptiveAvgPool2d: 1-9                 --
# ├─Linear: 1-10                           5,130
# =================================================================
# Total params: 21,282,122
# Trainable params: 21,282,122
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Student model

# %%
Student = resnet18(num_classes=10)  # commment out this line if loading trained student model
# Student = torch.load('Student.pt')  # loading trained student model
Student = Student.to(device)

# %%
summary(Student)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ResNet                                   --
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─ReLU: 1-3                              --
# ├─MaxPool2d: 1-4                         --
# ├─Sequential: 1-5                        --
# │    └─BasicBlock: 2-1                   --
# │    │    └─Conv2d: 3-1                  36,864
# │    │    └─BatchNorm2d: 3-2             128
# │    │    └─ReLU: 3-3                    --
# │    │    └─Conv2d: 3-4                  36,864
# │    │    └─BatchNorm2d: 3-5             128
# │    └─BasicBlock: 2-2                   --
# │    │    └─Conv2d: 3-6                  36,864
# │    │    └─BatchNorm2d: 3-7             128
# │    │    └─ReLU: 3-8                    --
# │    │    └─Conv2d: 3-9                  36,864
# │    │    └─BatchNorm2d: 3-10            128
# ├─Sequential: 1-6                        --
# │    └─BasicBlock: 2-3                   --
# │    │    └─Conv2d: 3-11                 73,728
# │    │    └─BatchNorm2d: 3-12            256
# │    │    └─ReLU: 3-13                   --
# │    │    └─Conv2d: 3-14                 147,456
# │    │    └─BatchNorm2d: 3-15            256
# │    │    └─Sequential: 3-16             8,448
# │    └─BasicBlock: 2-4                   --
# │    │    └─Conv2d: 3-17                 147,456
# │    │    └─BatchNorm2d: 3-18            256
# │    │    └─ReLU: 3-19                   --
# │    │    └─Conv2d: 3-20                 147,456
# │    │    └─BatchNorm2d: 3-21            256
# ├─Sequential: 1-7                        --
# │    └─BasicBlock: 2-5                   --
# │    │    └─Conv2d: 3-22                 294,912
# │    │    └─BatchNorm2d: 3-23            512
# │    │    └─ReLU: 3-24                   --
# │    │    └─Conv2d: 3-25                 589,824
# │    │    └─BatchNorm2d: 3-26            512
# │    │    └─Sequential: 3-27             33,280
# │    └─BasicBlock: 2-6                   --
# │    │    └─Conv2d: 3-28                 589,824
# │    │    └─BatchNorm2d: 3-29            512
# │    │    └─ReLU: 3-30                   --
# │    │    └─Conv2d: 3-31                 589,824
# │    │    └─BatchNorm2d: 3-32            512
# ├─Sequential: 1-8                        --
# │    └─BasicBlock: 2-7                   --
# │    │    └─Conv2d: 3-33                 1,179,648
# │    │    └─BatchNorm2d: 3-34            1,024
# │    │    └─ReLU: 3-35                   --
# │    │    └─Conv2d: 3-36                 2,359,296
# │    │    └─BatchNorm2d: 3-37            1,024
# │    │    └─Sequential: 3-38             132,096
# │    └─BasicBlock: 2-8                   --
# │    │    └─Conv2d: 3-39                 2,359,296
# │    │    └─BatchNorm2d: 3-40            1,024
# │    │    └─ReLU: 3-41                   --
# │    │    └─Conv2d: 3-42                 2,359,296
# │    │    └─BatchNorm2d: 3-43            1,024
# ├─AdaptiveAvgPool2d: 1-9                 --
# ├─Linear: 1-10                           5,130
# =================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# # Define training and testing function

# %%
def train_from_scratch(model, train_loader, val_loader, epochs=10, learning_rate=1e-3, device="cuda", save_path=None):
    if save_path is None:
        save_path = f'weights/{model.__class__.__name__}.pt'

    criterion = nn.CrossEntropyLoss()
    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.Adam(params, lr=learning_rate)

    loss = []
    train_error=[]
    val_error = []
    valdation_error = []
    train_loss = []
    valdation_loss = []
    train_accuraacy = []
    valdation_accuracy= []
    best_acc = 0.0

    for epoch in range(epochs):
        train_loss = 0.0
        valid_loss = 0.0
        train_acc = 0.0
        valid_acc = 0.0
        correct = 0
        total = 0
        V_correct = 0
        V_total = 0

        model.train()
        train_bar = tqdm(train_loader, file=sys.stdout)
        for step, data in enumerate(train_bar):
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            logits, hidden = model(images)
            loss = criterion(logits, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * images.size(0)
            pred = logits.data.max(1, keepdim=True)[1]
            correct += np.sum(np.squeeze(pred.eq(labels.data.view_as(pred))).cpu().numpy())
            total += images.size(0)
            train_acc =  correct/total
            train_bar.desc = "train epoch[{}/{}]".format(epoch + 1, epochs)

        model.eval()
        with torch.no_grad():
            val_bar = tqdm(val_loader, file=sys.stdout)
            for val_data in val_bar:
                val_images, val_labels = val_data
                val_images, val_labels = val_images.to(device), val_labels.to(device)
                outputs, hidden_outputs = model(val_images)
                loss = criterion(outputs, val_labels)
                valid_loss += loss.item() * val_images.size(0)
                pred = outputs.data.max(1, keepdim=True)[1]
                V_correct += np.sum(np.squeeze(pred.eq(val_labels.data.view_as(pred))).cpu().numpy())
                V_total += val_images.size(0)
                val_bar.desc = "valid epoch[{}/{}]".format(epoch + 1, epochs)

        train_loss = train_loss / len(train_loader.dataset)
        train_error.append(train_loss)
        valid_loss = valid_loss / len(val_loader.dataset)
        val_error.append(valid_loss)
        train_accuraacy.append( correct / total)
        valdation_accuracy.append(V_correct / V_total)

        print('\tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(train_loss, valid_loss))
        print(f'\tTrain Accuracy: {100. * correct / total:.3f}% ({correct}/{total})\tValidation Accuracy: {100. * V_correct / V_total:.3f}% ({V_correct}/{V_total})')

        # save the best model
        if epoch == 0 or best_acc < V_correct / V_total:
            best_acc = V_correct / V_total
            os.makedirs(os.path.dirname(save_path), exist_ok=True)
            torch.save(model, save_path)

    print('Finished Training')

# %%
def test(model, test_loader, device, type=None):
    criterion = nn.CrossEntropyLoss()
    acc = 0.0
    test_loss = 0.0

    if type == None:
        model.eval()
    elif type == 'distiller':
        model.eval()
        model.teacher.eval()
        model.student.eval()
    else:
       raise ValueError(f'Error: only support response-based and feature-based distillation')

    with torch.no_grad():
        test_bar = tqdm(test_loader, file=sys.stdout)
        for test_data in test_bar:
            test_images, test_labels = test_data
            test_images, test_labels = test_images.to(device), test_labels.to(device)
            if type == None:
                outputs, features = model(test_images)
                loss = criterion(outputs, test_labels)
            elif type == 'distiller':
                outputs, loss = model(test_images, test_labels)
            else:
                raise ValueError(f'Error: only support response-based and feature-based distillation')

            predict_y = torch.max(outputs, dim=1)[1]
            acc += torch.eq(predict_y, test_labels.to(device)).sum().item()
            test_loss += loss.item()
            test_bar.desc = "test"

    test_accurate = acc / test_num
    print('test_loss: %.3f  test_accuracy: %.3f' %(test_loss / test_steps, test_accurate * 100))
    return test_loss / test_steps, test_accurate * 100.

# %% [markdown]
# # The influence of temperuture

# %%
logits = np.array([-5, 2, 7, 9])

# %%
T = 1
softmax_1 = np.exp(logits/T) / sum(np.exp(logits/T))
plt.plot(softmax_1, label='T=1')

T = 2
softmax_2 = np.exp(logits/T) / sum(np.exp(logits/T))
plt.plot(softmax_2, label='T=2')

T = 5
softmax_5 = np.exp(logits/T) / sum(np.exp(logits/T))
plt.plot(softmax_5, label='T=5')

T = 10
softmax_10 = np.exp(logits/T) / sum(np.exp(logits/T))
plt.plot(softmax_10, label='T=10')

T = 100
softmax_100 = np.exp(logits/T) / sum(np.exp(logits/T))
plt.plot(softmax_100, label='T=100')

plt.xticks(np.arange(4), ['Cat', 'Dog', 'Bird', 'Rabbit'])
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Define distillation fuction

# %%
#####################################################################
# Finish the loss function for response-based distillation. #
#####################################################################
def loss_re(student_logits, teacher_logits, target, T=1, alpha=0.1):
    hard_loss = F.cross_entropy(student_logits, target)
    soft_loss = F.kl_div(
        F.log_softmax(student_logits / T, dim=1),
        F.softmax(teacher_logits / T, dim=1),
        reduction="batchmean",
    )
    loss = alpha * T**2 * soft_loss + (1 - alpha) * hard_loss
    return loss

# %%
####################################################################
# Finish the loss function for feature-based distillation. #
####################################################################
def loss_fe(student_logits, student_features, teacher_features, target, beta=0.1):
    ce_loss = F.cross_entropy(student_logits, target)
    fm_loss = 0.0
    for student_feature, teacher_feature in zip(student_features, teacher_features):
        fm_loss += F.mse_loss(student_feature, teacher_feature)
    return ce_loss + beta * fm_loss

# %%
class Distiller(nn.Module):
    def __init__(self, teacher, student, type, temperature=4, alpha=0.5, beta=0.5):
        super(Distiller, self).__init__()

        ########################################
        # 1. Finish the __init__ method. #
        ########################################

        self.type = type
        self.teacher = teacher
        self.student = student
        self.temperature = temperature
        self.alpha = alpha
        self.beta = beta

    def forward(self, x, target):

        #####################################
        # 2. Finish the forward pass. #
        #####################################

        self.teacher.eval()
        self.student.train()
        student_logits, student_features = self.student(x)
        teacher_logits, teacher_features = self.teacher(x)

        if self.type.lower() == 'response':
            loss_distill = loss_re(student_logits, teacher_logits, target, T=self.temperature, alpha=self.alpha)
        elif self.type.lower() == 'feature':
            loss_distill = loss_fe(student_logits, student_features, teacher_features, target, beta=self.beta)
        else:
            raise ValueError(f'Error: only support response-based and feature-based distillation')

        return student_logits, loss_distill

# %%
def train_distillation(distiller, student, train_loader, val_loader, epochs=10, learning_rate=1e-3, device="cuda"):
    ce_loss = nn.CrossEntropyLoss()
    ###########################
    # define the optimizer #
    ###########################
    optimizer = torch.optim.Adam(distiller.student.parameters() , lr=learning_rate)

    loss = []
    train_error=[]
    val_error = []
    train_loss = []
    train_accuraacy = []
    valdation_accuracy= []

    for epoch in range(epochs):
        distiller.train()
        distiller.teacher.train()
        distiller.student.train()

        train_loss = 0.0
        valid_loss = 0.0
        train_acc = 0.0
        valid_acc  = 0.0
        correct = 0
        total = 0
        V_correct = 0
        V_total = 0
        train_bar = tqdm(train_loader, file=sys.stdout)
        for step, data in enumerate(train_bar):
            images, labels = data
            images, labels = images.to(device), labels.to(device)

            outputs, loss = distiller(images, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * images.size(0)
            pred = outputs.data.max(1, keepdim=True)[1]
            result = pred.eq(labels.data.view_as(pred))
            result = np.squeeze(result.cpu().numpy())
            correct += np.sum(result)
            total += images.size(0)
            train_bar.desc = "train epoch[{}/{}]".format(epoch + 1, epochs)

        distiller.eval()
        distiller.teacher.eval()
        distiller.student.eval()

        with torch.no_grad():
            val_bar = tqdm(val_loader, file=sys.stdout)
            for val_data in val_bar:

                val_images, val_labels = val_data
                val_images, val_labels = val_images.to(device), val_labels.to(device)

                outputs, loss = distiller(val_images, val_labels)

                valid_loss += loss.item() * val_images.size(0)
                pred = outputs.max(1, keepdim=True)[1]
                V_correct += np.sum(np.squeeze(pred.eq(val_labels.data.view_as(pred))).cpu().numpy())
                V_total += val_images.size(0)
                val_bar.desc = "valid epoch[{}/{}]".format(epoch + 1, epochs)

        train_loss = train_loss / len(train_loader.dataset)
        train_error.append(train_loss)
        valid_loss = valid_loss / len(val_loader.dataset)
        val_error.append(valid_loss)
        train_accuraacy.append( correct / total)
        valdation_accuracy.append(V_correct / V_total)

        print('\tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(train_loss, valid_loss))
        print(f'\tTrain Accuracy: {100. * correct / total:.3f}% ({correct}/{total})\tValidation Accuracy: {100. * V_correct / V_total:.3f}% ({V_correct}/{V_total})')

    print('Finished Distilling')

# %% [markdown]
# # Train Teacher and Student model from scratch

# %%
#############################################
# Decide the epochs and learning rate #
#############################################
train_from_scratch(Teacher, train_loader, val_loader, epochs=20, learning_rate=1e-3, device=device, save_path='weights/resnet34.pt')
# Out:
# train epoch[1/20]: 100%|██████████| 313/313 [00:09<00:00, 33.11it/s]
# valid epoch[1/20]: 100%|██████████| 79/79 [00:01<00:00, 49.36it/s]
# 	Training Loss: 1.530377 	Validation Loss: 1.500062
# 	Train Accuracy: 43.755% (17502/40000)	Validation Accuracy: 48.060% (4806/10000)
# train epoch[2/20]: 100%|██████████| 313/313 [00:09<00:00, 34.30it/s]
# valid epoch[2/20]: 100%|██████████| 79/79 [00:01<00:00, 58.40it/s]
# 	Training Loss: 1.120418 	Validation Loss: 1.197817
# 	Train Accuracy: 60.297% (24119/40000)	Validation Accuracy: 57.390% (5739/10000)
# train epoch[3/20]: 100%|██████████| 313/313 [00:07<00:00, 39.81it/s]
# valid epoch[3/20]: 100%|██████████| 79/79 [00:01<00:00, 52.68it/s]
# 	Training Loss: 0.904218 	Validation Loss: 0.971273
# 	Train Accuracy: 68.635% (27454/40000)	Validation Accuracy: 66.730% (6673/10000)
# train epoch[4/20]: 100%|██████████| 313/313 [00:09<00:00, 32.02it/s]
# valid epoch[4/20]: 100%|██████████| 79/79 [00:01<00:00, 53.29it/s]
# 	Training Loss: 0.772588 	Validation Loss: 0.791760
# 	Train Accuracy: 73.287% (29315/40000)	Validation Accuracy: 73.030% (7303/10000)
# train epoch[5/20]: 100%|██████████| 313/313 [00:09<00:00, 31.93it/s]
# valid epoch[5/20]: 100%|██████████| 79/79 [00:01<00:00, 55.08it/s]
# 	Training Loss: 0.683951 	Validation Loss: 0.725154
# 	Train Accuracy: 76.380% (30552/40000)	Validation Accuracy: 75.480% (7548/10000)
# train epoch[6/20]: 100%|██████████| 313/313 [00:09<00:00, 32.05it/s]
# valid epoch[6/20]: 100%|██████████| 79/79 [00:01<00:00, 53.28it/s]
# 	Training Loss: 0.626252 	Validation Loss: 0.709044
# 	Train Accuracy: 78.485% (31394/40000)	Validation Accuracy: 75.940% (7594/10000)
# train epoch[7/20]: 100%|██████████| 313/313 [00:09<00:00, 31.83it/s]
# valid epoch[7/20]: 100%|██████████| 79/79 [00:01<00:00, 53.40it/s]
# 	Training Loss: 0.565447 	Validation Loss: 0.667831
# 	Train Accuracy: 80.625% (32250/40000)	Validation Accuracy: 77.500% (7750/10000)
# train epoch[8/20]: 100%|██████████| 313/313 [00:09<00:00, 32.00it/s]
# valid epoch[8/20]: 100%|██████████| 79/79 [00:01<00:00, 54.98it/s]
# 	Training Loss: 0.522372 	Validation Loss: 0.687990
# 	Train Accuracy: 82.130% (32852/40000)	Validation Accuracy: 77.480% (7748/10000)
# train epoch[9/20]: 100%|██████████| 313/313 [00:09<00:00, 31.84it/s]
# valid epoch[9/20]: 100%|██████████| 79/79 [00:01<00:00, 53.01it/s]
# 	Training Loss: 0.486489 	Validation Loss: 0.677362
# 	Train Accuracy: 83.422% (33369/40000)	Validation Accuracy: 77.670% (7767/10000)
# train epoch[10/20]: 100%|██████████| 313/313 [00:09<00:00, 31.99it/s]
# valid epoch[10/20]: 100%|██████████| 79/79 [00:01<00:00, 53.59it/s]
# 	Training Loss: 0.458201 	Validation Loss: 0.593416
# 	Train Accuracy: 84.300% (33720/40000)	Validation Accuracy: 80.240% (8024/10000)
# train epoch[11/20]: 100%|██████████| 313/313 [00:09<00:00, 32.39it/s]
# valid epoch[11/20]: 100%|██████████| 79/79 [00:01<00:00, 53.45it/s]
# 	Training Loss: 0.431298 	Validation Loss: 0.550854
# 	Train Accuracy: 85.207% (34083/40000)	Validation Accuracy: 81.260% (8126/10000)
# train epoch[12/20]: 100%|██████████| 313/313 [00:07<00:00, 43.82it/s]
# valid epoch[12/20]: 100%|██████████| 79/79 [00:01<00:00, 55.71it/s]
# 	Training Loss: 0.408698 	Validation Loss: 0.540078
# 	Train Accuracy: 86.020% (34408/40000)	Validation Accuracy: 81.900% (8190/10000)
# train epoch[13/20]: 100%|██████████| 313/313 [00:09<00:00, 33.48it/s]
# valid epoch[13/20]: 100%|██████████| 79/79 [00:01<00:00, 55.61it/s]
# 	Training Loss: 0.382770 	Validation Loss: 0.605364
# 	Train Accuracy: 86.950% (34780/40000)	Validation Accuracy: 80.530% (8053/10000)
# train epoch[14/20]: 100%|██████████| 313/313 [00:08<00:00, 34.81it/s]
# valid epoch[14/20]: 100%|██████████| 79/79 [00:01<00:00, 68.35it/s]
# 	Training Loss: 0.367065 	Validation Loss: 0.513900
# 	Train Accuracy: 87.343% (34937/40000)	Validation Accuracy: 83.110% (8311/10000)
# train epoch[15/20]: 100%|██████████| 313/313 [00:08<00:00, 36.45it/s]
# valid epoch[15/20]: 100%|██████████| 79/79 [00:01<00:00, 54.47it/s]
# 	Training Loss: 0.348269 	Validation Loss: 0.549432
# 	Train Accuracy: 88.123% (35249/40000)	Validation Accuracy: 82.240% (8224/10000)
# train epoch[16/20]: 100%|██████████| 313/313 [00:09<00:00, 32.02it/s]
# valid epoch[16/20]: 100%|██████████| 79/79 [00:01<00:00, 52.72it/s]
# 	Training Loss: 0.324150 	Validation Loss: 0.489248
# 	Train Accuracy: 88.595% (35438/40000)	Validation Accuracy: 83.700% (8370/10000)
# train epoch[17/20]: 100%|██████████| 313/313 [00:09<00:00, 31.92it/s]
# valid epoch[17/20]: 100%|██████████| 79/79 [00:01<00:00, 52.95it/s]
# 	Training Loss: 0.307743 	Validation Loss: 0.495265
# 	Train Accuracy: 89.495% (35798/40000)	Validation Accuracy: 84.010% (8401/10000)
# train epoch[18/20]: 100%|██████████| 313/313 [00:09<00:00, 31.96it/s]
# valid epoch[18/20]: 100%|██████████| 79/79 [00:01<00:00, 54.44it/s]
# 	Training Loss: 0.295919 	Validation Loss: 0.483596
# 	Train Accuracy: 89.670% (35868/40000)	Validation Accuracy: 84.650% (8465/10000)
# train epoch[19/20]: 100%|██████████| 313/313 [00:09<00:00, 32.01it/s]
# valid epoch[19/20]: 100%|██████████| 79/79 [00:01<00:00, 52.95it/s]
# 	Training Loss: 0.284387 	Validation Loss: 0.487240
# 	Train Accuracy: 90.017% (36007/40000)	Validation Accuracy: 84.170% (8417/10000)
# train epoch[20/20]: 100%|██████████| 313/313 [00:09<00:00, 32.00it/s]
# valid epoch[20/20]: 100%|██████████| 79/79 [00:01<00:00, 53.13it/s]
# 	Training Loss: 0.268413 	Validation Loss: 0.432394
# 	Train Accuracy: 90.707% (36283/40000)	Validation Accuracy: 86.250% (8625/10000)
# Finished Training

# %%
T_loss, T_accuracy = test(Teacher, test_loader, device=device)
# Out:
# test: 100%|██████████| 79/79 [00:00<00:00, 80.74it/s]
# test_loss: 0.418  test_accuracy: 86.620

# %%
#############################################
# Decide the epochs and learning rate #
#############################################
train_from_scratch(Student, train_loader, val_loader, epochs=20, learning_rate=1e-3, device=device, save_path='weights/resnet18.pt')
# Out:
# train epoch[1/20]: 100%|██████████| 313/313 [00:07<00:00, 41.84it/s]
# valid epoch[1/20]: 100%|██████████| 79/79 [00:01<00:00, 60.11it/s]
# 	Training Loss: 1.408782 	Validation Loss: 1.315130
# 	Train Accuracy: 48.752% (19501/40000)	Validation Accuracy: 54.960% (5496/10000)
# train epoch[2/20]: 100%|██████████| 313/313 [00:07<00:00, 42.50it/s]
# valid epoch[2/20]: 100%|██████████| 79/79 [00:01<00:00, 62.68it/s]
# 	Training Loss: 1.007155 	Validation Loss: 1.005944
# 	Train Accuracy: 64.422% (25769/40000)	Validation Accuracy: 65.220% (6522/10000)
# train epoch[3/20]: 100%|██████████| 313/313 [00:07<00:00, 43.26it/s]
# valid epoch[3/20]: 100%|██████████| 79/79 [00:01<00:00, 63.97it/s]
# 	Training Loss: 0.834525 	Validation Loss: 0.903660
# 	Train Accuracy: 71.045% (28418/40000)	Validation Accuracy: 68.630% (6863/10000)
# train epoch[4/20]: 100%|██████████| 313/313 [00:06<00:00, 51.09it/s]
# valid epoch[4/20]: 100%|██████████| 79/79 [00:00<00:00, 81.88it/s]
# 	Training Loss: 0.713867 	Validation Loss: 0.818532
# 	Train Accuracy: 75.115% (30046/40000)	Validation Accuracy: 71.970% (7197/10000)
# train epoch[5/20]: 100%|██████████| 313/313 [00:06<00:00, 46.49it/s]
# valid epoch[5/20]: 100%|██████████| 79/79 [00:01<00:00, 60.81it/s]
# 	Training Loss: 0.640060 	Validation Loss: 0.677840
# 	Train Accuracy: 77.890% (31156/40000)	Validation Accuracy: 76.770% (7677/10000)
# train epoch[6/20]: 100%|██████████| 313/313 [00:07<00:00, 43.24it/s]
# valid epoch[6/20]: 100%|██████████| 79/79 [00:01<00:00, 65.42it/s]
# 	Training Loss: 0.586466 	Validation Loss: 0.658508
# 	Train Accuracy: 79.897% (31959/40000)	Validation Accuracy: 77.530% (7753/10000)
# train epoch[7/20]: 100%|██████████| 313/313 [00:06<00:00, 49.57it/s]
# valid epoch[7/20]: 100%|██████████| 79/79 [00:00<00:00, 82.93it/s]
# 	Training Loss: 0.542107 	Validation Loss: 0.627767
# 	Train Accuracy: 81.370% (32548/40000)	Validation Accuracy: 78.710% (7871/10000)
# train epoch[8/20]: 100%|██████████| 313/313 [00:06<00:00, 46.49it/s]
# valid epoch[8/20]: 100%|██████████| 79/79 [00:01<00:00, 59.63it/s]
# 	Training Loss: 0.496753 	Validation Loss: 0.658846
# 	Train Accuracy: 82.895% (33158/40000)	Validation Accuracy: 78.560% (7856/10000)
# train epoch[9/20]: 100%|██████████| 313/313 [00:07<00:00, 41.85it/s]
# valid epoch[9/20]: 100%|██████████| 79/79 [00:01<00:00, 58.75it/s]
# 	Training Loss: 0.475171 	Validation Loss: 0.612971
# 	Train Accuracy: 83.412% (33365/40000)	Validation Accuracy: 79.450% (7945/10000)
# train epoch[10/20]: 100%|██████████| 313/313 [00:07<00:00, 41.68it/s]
# valid epoch[10/20]: 100%|██████████| 79/79 [00:01<00:00, 57.94it/s]
# 	Training Loss: 0.450682 	Validation Loss: 0.570641
# 	Train Accuracy: 84.392% (33757/40000)	Validation Accuracy: 81.130% (8113/10000)
# train epoch[11/20]: 100%|██████████| 313/313 [00:07<00:00, 41.63it/s]
# valid epoch[11/20]: 100%|██████████| 79/79 [00:01<00:00, 58.67it/s]
# 	Training Loss: 0.415712 	Validation Loss: 0.556625
# 	Train Accuracy: 85.560% (34224/40000)	Validation Accuracy: 81.260% (8126/10000)
# train epoch[12/20]: 100%|██████████| 313/313 [00:07<00:00, 41.68it/s]
# valid epoch[12/20]: 100%|██████████| 79/79 [00:01<00:00, 58.37it/s]
# 	Training Loss: 0.396602 	Validation Loss: 0.515252
# 	Train Accuracy: 86.282% (34513/40000)	Validation Accuracy: 82.620% (8262/10000)
# train epoch[13/20]: 100%|██████████| 313/313 [00:07<00:00, 41.34it/s]
# valid epoch[13/20]: 100%|██████████| 79/79 [00:01<00:00, 59.32it/s]
# 	Training Loss: 0.373016 	Validation Loss: 0.502857
# 	Train Accuracy: 87.103% (34841/40000)	Validation Accuracy: 83.160% (8316/10000)
# train epoch[14/20]: 100%|██████████| 313/313 [00:07<00:00, 41.86it/s]
# valid epoch[14/20]: 100%|██████████| 79/79 [00:01<00:00, 61.02it/s]
# 	Training Loss: 0.357395 	Validation Loss: 0.504835
# 	Train Accuracy: 87.618% (35047/40000)	Validation Accuracy: 83.350% (8335/10000)
# train epoch[15/20]: 100%|██████████| 313/313 [00:07<00:00, 41.67it/s]
# valid epoch[15/20]: 100%|██████████| 79/79 [00:01<00:00, 60.69it/s]
# 	Training Loss: 0.336181 	Validation Loss: 0.612040
# 	Train Accuracy: 88.195% (35278/40000)	Validation Accuracy: 80.450% (8045/10000)
# train epoch[16/20]: 100%|██████████| 313/313 [00:07<00:00, 42.15it/s]
# valid epoch[16/20]: 100%|██████████| 79/79 [00:01<00:00, 62.89it/s]
# 	Training Loss: 0.322618 	Validation Loss: 0.511151
# 	Train Accuracy: 88.825% (35530/40000)	Validation Accuracy: 83.340% (8334/10000)
# train epoch[17/20]: 100%|██████████| 313/313 [00:07<00:00, 42.74it/s]
# valid epoch[17/20]: 100%|██████████| 79/79 [00:01<00:00, 61.76it/s]
# 	Training Loss: 0.308738 	Validation Loss: 0.495456
# 	Train Accuracy: 89.345% (35738/40000)	Validation Accuracy: 83.900% (8390/10000)
# train epoch[18/20]: 100%|██████████| 313/313 [00:05<00:00, 53.09it/s]
# valid epoch[18/20]: 100%|██████████| 79/79 [00:00<00:00, 81.51it/s]
# 	Training Loss: 0.289860 	Validation Loss: 0.481872
# 	Train Accuracy: 90.015% (36006/40000)	Validation Accuracy: 84.590% (8459/10000)
# train epoch[19/20]: 100%|██████████| 313/313 [00:05<00:00, 61.33it/s]
# valid epoch[19/20]: 100%|██████████| 79/79 [00:00<00:00, 82.18it/s]
# 	Training Loss: 0.273961 	Validation Loss: 0.496649
# 	Train Accuracy: 90.567% (36227/40000)	Validation Accuracy: 84.030% (8403/10000)
# train epoch[20/20]: 100%|██████████| 313/313 [00:06<00:00, 50.49it/s]
# valid epoch[20/20]: 100%|██████████| 79/79 [00:01<00:00, 60.54it/s]
# 	Training Loss: 0.262052 	Validation Loss: 0.484675
# 	Train Accuracy: 90.780% (36312/40000)	Validation Accuracy: 84.700% (8470/10000)
# Finished Training

# %%
S_loss, S_accuracy = test(Student, test_loader, device=device)
# Out:
# test: 100%|██████████| 79/79 [00:00<00:00, 93.75it/s]
# test_loss: 0.492  test_accuracy: 84.820

# %% [markdown]
# # Response-based distillation

# %%
#############################################
# Decide the epochs and learning rate #
#############################################
Student_re = resnet18(num_classes=10).to(device)
distiller_re = Distiller(Teacher, Student_re, type='response')
train_distillation(distiller_re, Student_re, train_loader, val_loader, epochs=20, learning_rate=1e-3, device=device)
# Out:
# train epoch[1/20]: 100%|██████████| 313/313 [00:11<00:00, 27.56it/s]
# valid epoch[1/20]: 100%|██████████| 79/79 [00:01<00:00, 52.37it/s]
# 	Training Loss: 3.249244 	Validation Loss: 2.082570
# 	Train Accuracy: 50.695% (20278/40000)	Validation Accuracy: 62.580% (6258/10000)
# train epoch[2/20]: 100%|██████████| 313/313 [00:09<00:00, 34.72it/s]
# valid epoch[2/20]: 100%|██████████| 79/79 [00:01<00:00, 47.33it/s]
# 	Training Loss: 1.772801 	Validation Loss: 1.407763
# 	Train Accuracy: 67.593% (27037/40000)	Validation Accuracy: 71.510% (7151/10000)
# train epoch[3/20]: 100%|██████████| 313/313 [00:11<00:00, 27.22it/s]
# valid epoch[3/20]: 100%|██████████| 79/79 [00:01<00:00, 49.12it/s]
# 	Training Loss: 1.275555 	Validation Loss: 1.145038
# 	Train Accuracy: 74.615% (29846/40000)	Validation Accuracy: 75.540% (7554/10000)
# train epoch[4/20]: 100%|██████████| 313/313 [00:11<00:00, 27.10it/s]
# valid epoch[4/20]: 100%|██████████| 79/79 [00:01<00:00, 49.08it/s]
# 	Training Loss: 1.005476 	Validation Loss: 0.940555
# 	Train Accuracy: 78.255% (31302/40000)	Validation Accuracy: 77.880% (7788/10000)
# train epoch[5/20]: 100%|██████████| 313/313 [00:11<00:00, 27.06it/s]
# valid epoch[5/20]: 100%|██████████| 79/79 [00:01<00:00, 49.24it/s]
# 	Training Loss: 0.852073 	Validation Loss: 0.808630
# 	Train Accuracy: 80.873% (32349/40000)	Validation Accuracy: 80.400% (8040/10000)
# train epoch[6/20]: 100%|██████████| 313/313 [00:11<00:00, 27.15it/s]
# valid epoch[6/20]: 100%|██████████| 79/79 [00:01<00:00, 49.29it/s]
# 	Training Loss: 0.757293 	Validation Loss: 0.728923
# 	Train Accuracy: 82.625% (33050/40000)	Validation Accuracy: 80.650% (8065/10000)
# train epoch[7/20]: 100%|██████████| 313/313 [00:11<00:00, 27.10it/s]
# valid epoch[7/20]: 100%|██████████| 79/79 [00:01<00:00, 48.79it/s]
# 	Training Loss: 0.674486 	Validation Loss: 0.708515
# 	Train Accuracy: 83.892% (33557/40000)	Validation Accuracy: 81.760% (8176/10000)
# train epoch[8/20]: 100%|██████████| 313/313 [00:11<00:00, 27.01it/s]
# valid epoch[8/20]: 100%|██████████| 79/79 [00:01<00:00, 49.47it/s]
# 	Training Loss: 0.624166 	Validation Loss: 0.683583
# 	Train Accuracy: 84.685% (33874/40000)	Validation Accuracy: 81.470% (8147/10000)
# train epoch[9/20]: 100%|██████████| 313/313 [00:11<00:00, 27.26it/s]
# valid epoch[9/20]: 100%|██████████| 79/79 [00:01<00:00, 50.71it/s]
# 	Training Loss: 0.589287 	Validation Loss: 0.612077
# 	Train Accuracy: 85.543% (34217/40000)	Validation Accuracy: 83.330% (8333/10000)
# train epoch[10/20]: 100%|██████████| 313/313 [00:10<00:00, 29.15it/s]
# valid epoch[10/20]: 100%|██████████| 79/79 [00:01<00:00, 67.35it/s]
# 	Training Loss: 0.539279 	Validation Loss: 0.583288
# 	Train Accuracy: 86.543% (34617/40000)	Validation Accuracy: 83.860% (8386/10000)
# train epoch[11/20]: 100%|██████████| 313/313 [00:09<00:00, 32.29it/s]
# valid epoch[11/20]: 100%|██████████| 79/79 [00:01<00:00, 49.34it/s]
# 	Training Loss: 0.519360 	Validation Loss: 0.579673
# 	Train Accuracy: 86.892% (34757/40000)	Validation Accuracy: 83.470% (8347/10000)
# train epoch[12/20]: 100%|██████████| 313/313 [00:11<00:00, 27.06it/s]
# valid epoch[12/20]: 100%|██████████| 79/79 [00:01<00:00, 51.69it/s]
# 	Training Loss: 0.484216 	Validation Loss: 0.530068
# 	Train Accuracy: 87.565% (35026/40000)	Validation Accuracy: 84.630% (8463/10000)
# train epoch[13/20]: 100%|██████████| 313/313 [00:09<00:00, 32.26it/s]
# valid epoch[13/20]: 100%|██████████| 79/79 [00:01<00:00, 48.68it/s]
# 	Training Loss: 0.466991 	Validation Loss: 0.544889
# 	Train Accuracy: 88.228% (35291/40000)	Validation Accuracy: 84.680% (8468/10000)
# train epoch[14/20]: 100%|██████████| 313/313 [00:11<00:00, 27.06it/s]
# valid epoch[14/20]: 100%|██████████| 79/79 [00:01<00:00, 49.08it/s]
# 	Training Loss: 0.448037 	Validation Loss: 0.550810
# 	Train Accuracy: 88.425% (35370/40000)	Validation Accuracy: 84.400% (8440/10000)
# train epoch[15/20]: 100%|██████████| 313/313 [00:11<00:00, 27.11it/s]
# valid epoch[15/20]: 100%|██████████| 79/79 [00:01<00:00, 49.32it/s]
# 	Training Loss: 0.434157 	Validation Loss: 0.518593
# 	Train Accuracy: 89.025% (35610/40000)	Validation Accuracy: 85.320% (8532/10000)
# train epoch[16/20]: 100%|██████████| 313/313 [00:11<00:00, 27.10it/s]
# valid epoch[16/20]: 100%|██████████| 79/79 [00:01<00:00, 49.10it/s]
# 	Training Loss: 0.417790 	Validation Loss: 0.514574
# 	Train Accuracy: 89.388% (35755/40000)	Validation Accuracy: 85.390% (8539/10000)
# train epoch[17/20]: 100%|██████████| 313/313 [00:11<00:00, 27.13it/s]
# valid epoch[17/20]: 100%|██████████| 79/79 [00:01<00:00, 48.84it/s]
# 	Training Loss: 0.401582 	Validation Loss: 0.515739
# 	Train Accuracy: 89.778% (35911/40000)	Validation Accuracy: 85.340% (8534/10000)
# train epoch[18/20]: 100%|██████████| 313/313 [00:11<00:00, 27.08it/s]
# valid epoch[18/20]: 100%|██████████| 79/79 [00:01<00:00, 49.39it/s]
# 	Training Loss: 0.399188 	Validation Loss: 0.493235
# 	Train Accuracy: 89.743% (35897/40000)	Validation Accuracy: 85.680% (8568/10000)
# train epoch[19/20]: 100%|██████████| 313/313 [00:11<00:00, 27.13it/s]
# valid epoch[19/20]: 100%|██████████| 79/79 [00:01<00:00, 49.50it/s]
# 	Training Loss: 0.379812 	Validation Loss: 0.514262
# 	Train Accuracy: 90.368% (36147/40000)	Validation Accuracy: 85.920% (8592/10000)
# train epoch[20/20]: 100%|██████████| 313/313 [00:11<00:00, 27.52it/s]
# valid epoch[20/20]: 100%|██████████| 79/79 [00:01<00:00, 49.76it/s]
# 	Training Loss: 0.375091 	Validation Loss: 0.460196
# 	Train Accuracy: 90.573% (36229/40000)	Validation Accuracy: 86.290% (8629/10000)
# Finished Distilling

# %%
reS_loss, reS_accuracy = test(distiller_re, test_loader, type='distiller', device=device)
# Out:
# test: 100%|██████████| 79/79 [00:01<00:00, 69.26it/s]
# test_loss: 0.583  test_accuracy: 85.580

# %% [markdown]
# # Feature-based distillation

# %%
#############################################
# Decide the epochs and learning rate #
#############################################
Student_fe = resnet18(num_classes=10).to(device)
distiller_fe = Distiller(Teacher, Student_fe, type='feature')
train_distillation(distiller_fe, Student_fe, train_loader, val_loader, epochs=20, learning_rate=1e-3, device=device)
# Out:
# train epoch[1/20]: 100%|██████████| 313/313 [00:09<00:00, 31.61it/s]
# valid epoch[1/20]: 100%|██████████| 79/79 [00:01<00:00, 67.80it/s]
# 	Training Loss: 5.771558 	Validation Loss: 4.291685
# 	Train Accuracy: 45.188% (18075/40000)	Validation Accuracy: 55.070% (5507/10000)
# train epoch[2/20]: 100%|██████████| 313/313 [00:10<00:00, 29.33it/s]
# valid epoch[2/20]: 100%|██████████| 79/79 [00:01<00:00, 49.47it/s]
# 	Training Loss: 3.784017 	Validation Loss: 3.275892
# 	Train Accuracy: 63.090% (25236/40000)	Validation Accuracy: 67.830% (6783/10000)
# train epoch[3/20]: 100%|██████████| 313/313 [00:11<00:00, 27.01it/s]
# valid epoch[3/20]: 100%|██████████| 79/79 [00:01<00:00, 59.70it/s]
# 	Training Loss: 2.991068 	Validation Loss: 2.867681
# 	Train Accuracy: 72.210% (28884/40000)	Validation Accuracy: 72.620% (7262/10000)
# train epoch[4/20]: 100%|██████████| 313/313 [00:10<00:00, 31.14it/s]
# valid epoch[4/20]: 100%|██████████| 79/79 [00:01<00:00, 48.82it/s]
# 	Training Loss: 2.617535 	Validation Loss: 2.441164
# 	Train Accuracy: 76.105% (30442/40000)	Validation Accuracy: 77.080% (7708/10000)
# train epoch[5/20]: 100%|██████████| 313/313 [00:11<00:00, 27.05it/s]
# valid epoch[5/20]: 100%|██████████| 79/79 [00:01<00:00, 48.79it/s]
# 	Training Loss: 2.300925 	Validation Loss: 2.202260
# 	Train Accuracy: 79.297% (31719/40000)	Validation Accuracy: 78.790% (7879/10000)
# train epoch[6/20]: 100%|██████████| 313/313 [00:11<00:00, 27.10it/s]
# valid epoch[6/20]: 100%|██████████| 79/79 [00:01<00:00, 48.93it/s]
# 	Training Loss: 2.125809 	Validation Loss: 2.104142
# 	Train Accuracy: 81.180% (32472/40000)	Validation Accuracy: 80.260% (8026/10000)
# train epoch[7/20]: 100%|██████████| 313/313 [00:11<00:00, 27.31it/s]
# valid epoch[7/20]: 100%|██████████| 79/79 [00:01<00:00, 48.69it/s]
# 	Training Loss: 1.942373 	Validation Loss: 1.959114
# 	Train Accuracy: 82.478% (32991/40000)	Validation Accuracy: 80.670% (8067/10000)
# train epoch[8/20]: 100%|██████████| 313/313 [00:11<00:00, 27.26it/s]
# valid epoch[8/20]: 100%|██████████| 79/79 [00:01<00:00, 49.12it/s]
# 	Training Loss: 1.834646 	Validation Loss: 1.910471
# 	Train Accuracy: 83.490% (33396/40000)	Validation Accuracy: 81.780% (8178/10000)
# train epoch[9/20]: 100%|██████████| 313/313 [00:11<00:00, 27.09it/s]
# valid epoch[9/20]: 100%|██████████| 79/79 [00:01<00:00, 49.09it/s]
# 	Training Loss: 1.753343 	Validation Loss: 1.814118
# 	Train Accuracy: 84.392% (33757/40000)	Validation Accuracy: 82.310% (8231/10000)
# train epoch[10/20]: 100%|██████████| 313/313 [00:11<00:00, 27.11it/s]
# valid epoch[10/20]: 100%|██████████| 79/79 [00:01<00:00, 49.63it/s]
# 	Training Loss: 1.649599 	Validation Loss: 1.706666
# 	Train Accuracy: 85.365% (34146/40000)	Validation Accuracy: 82.800% (8280/10000)
# train epoch[11/20]: 100%|██████████| 313/313 [00:11<00:00, 27.44it/s]
# valid epoch[11/20]: 100%|██████████| 79/79 [00:01<00:00, 50.16it/s]
# 	Training Loss: 1.603344 	Validation Loss: 1.624574
# 	Train Accuracy: 86.022% (34409/40000)	Validation Accuracy: 83.130% (8313/10000)
# train epoch[12/20]: 100%|██████████| 313/313 [00:09<00:00, 32.43it/s]
# valid epoch[12/20]: 100%|██████████| 79/79 [00:01<00:00, 69.32it/s]
# 	Training Loss: 1.511123 	Validation Loss: 1.623904
# 	Train Accuracy: 86.453% (34581/40000)	Validation Accuracy: 83.810% (8381/10000)
# train epoch[13/20]: 100%|██████████| 313/313 [00:11<00:00, 28.04it/s]
# valid epoch[13/20]: 100%|██████████| 79/79 [00:01<00:00, 50.37it/s]
# 	Training Loss: 1.468278 	Validation Loss: 1.528166
# 	Train Accuracy: 87.112% (34845/40000)	Validation Accuracy: 83.510% (8351/10000)
# train epoch[14/20]: 100%|██████████| 313/313 [00:11<00:00, 28.00it/s]
# valid epoch[14/20]: 100%|██████████| 79/79 [00:01<00:00, 63.24it/s]
# 	Training Loss: 1.425357 	Validation Loss: 1.600186
# 	Train Accuracy: 87.802% (35121/40000)	Validation Accuracy: 83.270% (8327/10000)
# train epoch[15/20]: 100%|██████████| 313/313 [00:10<00:00, 30.27it/s]
# valid epoch[15/20]: 100%|██████████| 79/79 [00:01<00:00, 48.84it/s]
# 	Training Loss: 1.382938 	Validation Loss: 1.467779
# 	Train Accuracy: 88.097% (35239/40000)	Validation Accuracy: 84.140% (8414/10000)
# train epoch[16/20]: 100%|██████████| 313/313 [00:11<00:00, 27.07it/s]
# valid epoch[16/20]: 100%|██████████| 79/79 [00:01<00:00, 49.00it/s]
# 	Training Loss: 1.323202 	Validation Loss: 1.416392
# 	Train Accuracy: 88.517% (35407/40000)	Validation Accuracy: 84.240% (8424/10000)
# train epoch[17/20]: 100%|██████████| 313/313 [00:11<00:00, 27.00it/s]
# valid epoch[17/20]: 100%|██████████| 79/79 [00:01<00:00, 48.40it/s]
# 	Training Loss: 1.319938 	Validation Loss: 1.413634
# 	Train Accuracy: 88.763% (35505/40000)	Validation Accuracy: 85.530% (8553/10000)
# train epoch[18/20]: 100%|██████████| 313/313 [00:11<00:00, 27.09it/s]
# valid epoch[18/20]: 100%|██████████| 79/79 [00:01<00:00, 48.55it/s]
# 	Training Loss: 1.271362 	Validation Loss: 1.679509
# 	Train Accuracy: 89.233% (35693/40000)	Validation Accuracy: 84.680% (8468/10000)
# train epoch[19/20]: 100%|██████████| 313/313 [00:11<00:00, 27.01it/s]
# valid epoch[19/20]: 100%|██████████| 79/79 [00:01<00:00, 48.94it/s]
# 	Training Loss: 1.236451 	Validation Loss: 1.363662
# 	Train Accuracy: 89.418% (35767/40000)	Validation Accuracy: 84.820% (8482/10000)
# train epoch[20/20]: 100%|██████████| 313/313 [00:11<00:00, 27.00it/s]
# valid epoch[20/20]: 100%|██████████| 79/79 [00:01<00:00, 48.81it/s]
# 	Training Loss: 1.222319 	Validation Loss: 1.346574
# 	Train Accuracy: 89.838% (35935/40000)	Validation Accuracy: 85.530% (8553/10000)
# Finished Distilling

# %%
ftS_loss, ftS_accuracy = test(distiller_fe, test_loader, type='distiller', device=device)
# Out:
# test: 100%|██████████| 79/79 [00:01<00:00, 68.11it/s]
# test_loss: 1.743  test_accuracy: 85.410

# %% [markdown]
# # Comparison

# %%
print(f'Teacher from scratch: loss={T_loss:.3f}, accuracy={T_accuracy:.2f}%')
print(f'Student from scratch: loss={S_loss:.3f}, accuracy={S_accuracy:.2f}%')
print(f'Response-based student: loss={reS_loss:.3f}, accuracy={reS_accuracy:.2f}%')
print(f'Filter-based student: loss={ftS_loss:.3f}, accuracy={ftS_accuracy:.2f}%')
# Out:
# Teacher from scratch: loss=0.418, accuracy=86.62%
# Student from scratch: loss=0.492, accuracy=84.82%
# Response-based student: loss=0.583, accuracy=85.58%
# Filter-based student: loss=1.743, accuracy=85.41%
